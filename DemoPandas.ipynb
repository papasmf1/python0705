# %%
#셀을 실행할 때 shift + enter 
import pandas 
#차트를 그리기 위해서 라이브러리 활성화 
# %pylab 
# %matplotlib inline 

#그림 그려달라~~ 
plot(arange(10))
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
from pandas import Series, DataFrame
import pandas as pd 

#주식의 가격(셀을 실행: shift + enter)
multicampus = Series([100,200,300,400,500])
multicampus
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# dtype: int64

# %%
multicampus2 = Series([100,200,300,400,500], 
    index=['07-05','07-06','07-07','07-08','07-09'])
multicampus2
# Out:
# 07-05    100
# 07-06    200
# 07-07    300
# 07-08    400
# 07-09    500
# dtype: int64

# %%
#특정 날짜로 슬라이싱
multicampus2['07-05']
# Out:
# 100

# %%
#딕셔너리를 저장해서 데이터프레임 
data = {"foreigner":[1,2,3,4,5,6],
        "sratio":[10,20,30,40,50,60],
        "org":[100,200,300,400,500,600],
        "sprice":[1,2,3,4,5,6],
        "private":[10,20,30,40,50,60] }

data
# Out:
# {'foreigner': [1, 2, 3, 4, 5, 6],
#  'sratio': [10, 20, 30, 40, 50, 60],
#  'org': [100, 200, 300, 400, 500, 600],
#  'sprice': [1, 2, 3, 4, 5, 6],
#  'private': [10, 20, 30, 40, 50, 60]}

# %%
frame1 = DataFrame(data)
#type(frame1)
frame1
# Out:
#    foreigner  sratio  org  sprice  private
# 0          1      10  100       1       10
# 1          2      20  200       2       20
# 2          3      30  300       3       30
# 3          4      40  400       4       40
# 4          5      50  500       5       50
# 5          6      60  600       6       60

# %%
frame1 = DataFrame(data, 
    columns=['foreigner','sratio','org','private','sprice'],
    index=['07-05','07-06','07-07','07-08','07-09','07-10'] )

frame1
# Out:
#        foreigner  sratio  org  private  sprice
# 07-05          1      10  100       10       1
# 07-06          2      20  200       20       2
# 07-07          3      30  300       30       3
# 07-08          4      40  400       40       4
# 07-09          5      50  500       50       5
# 07-10          6      60  600       60       6

# %%
frame1["private"]
# Out:
# 07-05    10
# 07-06    20
# 07-07    30
# 07-08    40
# 07-09    50
# 07-10    60
# Name: private, dtype: int64

# %%
frame1.loc["07-05"]
# Out:
# foreigner      1
# sratio        10
# org          100
# private       10
# sprice         1
# Name: 07-05, dtype: int64

# %%
frame1.T
# Out:
#            07-05  07-06  07-07  07-08  07-09  07-10
# foreigner      1      2      3      4      5      6
# sratio        10     20     30     40     50     60
# org          100    200    300    400    500    600
# private       10     20     30     40     50     60
# sprice         1      2      3      4      5      6

# %%
#데이터를 직접 볼 수 있다! 
# !type c:\work\ex1.csv
# Out:
# id, name, price, description
# 1, iphone, 890000, iphone 6s 7 8 x
# 2, android, 990000, samsung phone
# 3, winphone, 450000, microsoft winphone

# %%
import pandas as pd 
df = pd.read_csv('c:\\work\\ex1.csv')
df
# Out:
#    id       name   price           description
# 0   1     iphone  890000      iphone 6s 7 8 x
# 1   2    android  990000         samsung phone
# 2   3   winphone  450000   microsoft winphone

# %%
# !type c:\work\ex2.csv
# Out:
# 1, iphone, 890000, iphone 6s 7 8 x
# 2, android, 990000, samsung phone
# 3, winphone, 450000, microsoft winphone

# %%
df2 = pd.read_csv("c:\\work\\ex2.csv", 
    names=['id','name','price','description'])

df2
# Out:
#    id       name   price           description
# 0   1     iphone  890000      iphone 6s 7 8 x
# 1   2    android  990000         samsung phone
# 2   3   winphone  450000   microsoft winphone

# %%
# !type c:\work\ex3.txt
# Out:
# data1 data2 data3
# 1.2     2.3     1.3
# 0.1     1.5     2.5
# 3.1     3.2     3.3

# %%
result = pd.read_table('c:\\work\\ex3.txt', sep='\s+')

result
# Out:
#    data1  data2  data3
# 0    1.2    2.3    1.3
# 1    0.1    1.5    2.5
# 2    3.1    3.2    3.3

# %%
# %pylab 
# %matplotlib inline 
#엑셀파일을 데이터프레임으로 로딩
dfExcel = pd.read_excel('c:\\work\\demo.xlsx',
    'Sheet1')
#간단한 차트 
#비어 있는 그림판 추가
fig = plt.figure()
#하나의 차트 추가
ax = fig.add_subplot(1,1,1)
#히스토그램으로 나이컬럼을 7개의 그룹으로 그리기 
ax.hist(dfExcel['나이'], bins=7)
# Out:
# (array([1., 1., 2., 3., 1., 1., 1.]),
#  array([26.        , 28.57142857, 31.14285714, 33.71428571, 36.28571429,
#         38.85714286, 41.42857143, 44.        ]),
#  <BarContainer object of 7 artists>)

# %%
#데이터를 병합(merge)
df1 = DataFrame({'key':['b','b','a','c','a','a','b']
                , 'data1':range(7) })
df2 = DataFrame({'key':['a','b','d'], 
                 'data2':range(3) })

df2
# Out:
#   key  data2
# 0   a      0
# 1   b      1
# 2   d      2

# %%
pd.merge(df1, df2, on='key')
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   b      6      1
# 3   a      2      0
# 4   a      4      0
# 5   a      5      0

# %%
#데이터를 병합(merge):key컬럼이 다른 경우 
df3 = DataFrame({'lkey':['b','b','a','c','a','a','b']
                , 'data1':range(7) })
df4 = DataFrame({'rkey':['a','b','d'], 
                 'data2':range(3) })

pd.merge(df3, df4, left_on='lkey', right_on='rkey')
# Out:
#   lkey  data1 rkey  data2
# 0    b      0    b      1
# 1    b      1    b      1
# 2    b      6    b      1
# 3    a      2    a      0
# 4    a      4    a      0
# 5    a      5    a      0

# %%
#수직으로 데이터를 결합(concat)
s1 = Series([0,1], index=['a','b'])
s2 = Series([2,3,4], index=['c','d','e'])

pd.concat([s1,s2])
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# dtype: int64

# %%
import matplotlib.pyplot as plt 
import numpy as np 

t = np.arange(0, 12, 0.01)
y = np.sin(t)

plt.figure(figsize=(10,6))
plt.plot(t,y)
#약간의 꾸며주는 기능 
plt.grid()
plt.xlabel("time")
plt.ylabel("Amplitude")
plt.title("Sine Wave Demo")
# Out:
# Text(0.5, 1.0, 'Sine Wave Demo')
